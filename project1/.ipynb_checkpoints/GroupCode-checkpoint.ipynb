# %%
# %matplotlib inline
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
import community as community_louvain
import random
import time
import seaborn as sns
random.seed(1234)

text = []
title_one = "data/avengers-endgame.txt"
with open(title_one, "r", encoding='utf-8') as file:
	text = file.read()
       
text = text.replace("INT.","EXT.")
scenes = text.split("EXT.")
scenes.pop(0)

title_two = "data/characters.txt"

with open(title_two, "r", encoding = "utf-8") as file_two:
    text_two = file_two.read()

characters = text_two.split("\n")

characters_up = []
for i in characters:
    if i != '':
        characters_up.append(i.upper())

interact_data = pd.DataFrame(index = characters_up, columns = characters_up, data = 0)

all_charac_in_scene = []
for n in scenes:
    characters_in_scene = []
    for charac in characters_up:
        x = n.find(charac)
        if x != -1:
            characters_in_scene.append(charac)
    all_charac_in_scene.append(characters_in_scene)

print(all_charac_in_scene)


G = nx.Graph()
# Out:
# [['CLINT BARTON', 'LAURA BARTON'], [], ['TONY', 'NEBULA'], ['TONY'], ['TONY'], ['TONY', 'NEBULA'], ['TONY', 'NEBULA'], ['TONY'], ['TONY'], ['TONY'], ['TONY', 'NEBULA'], ['STEVE'], ['STEVE', 'TONY', 'BRUCE BANNER', 'NATASHA', 'ROCKET', 'NEBULA', 'PEPPER POTTS'], ['STEVE', 'TONY', 'THOR', 'NATASHA', 'RHODEY', 'SCOTT LANG', 'ROCKET', 'WONG', 'SECRETARY ROSS', 'T’CHALLA', 'DR. STRANGE', 'PETER PARKER', 'SAM WILSON', 'DRAX', 'MANTIS', 'GROOT', 'HOPE VAN DYNE', 'HANK PYM', 'NICK FURY', 'MARIA HILL', 'JANE FOSTER'], ['STEVE', 'TONY', 'NATASHA', 'RHODEY'], ['STEVE', 'NATASHA', 'RHODEY', 'NEBULA'], ['STEVE', 'THOR', 'BRUCE BANNER', 'NATASHA', 'RHODEY', 'ROCKET', 'NEBULA'], ['STEVE', 'NATASHA', 'RHODEY', 'ROCKET', 'NEBULA'], [], [], ['STEVE', 'NATASHA', 'NEBULA'], [], ['STEVE', 'THOR', 'BRUCE BANNER', 'NATASHA', 'RHODEY', 'ROCKET', 'NEBULA', 'THANOS'], [], [], [], ['STEVE'], [], ['SCOTT LANG', 'HANK PYM'], ['SCOTT LANG'], [], ['SCOTT LANG'], ['SCOTT LANG'], ['SCOTT LANG', 'CASSIE LANG'], [], ['STEVE', 'NATASHA', 'RHODEY', 'SCOTT LANG', 'ROCKET', 'NEBULA', 'OKOYE'], ['STEVE', 'NATASHA', 'SCOTT LANG'], [], ['STEVE', 'TONY'], ['STEVE', 'TONY', 'NATASHA', 'SCOTT LANG'], ['STEVE', 'NATASHA', 'SCOTT LANG'], ['SCOTT LANG'], ['STEVE', 'NATASHA', 'SCOTT LANG'], ['TONY', 'PETER PARKER'], ['TONY'], ['TONY'], ['TONY', 'PEPPER POTTS', 'HANK PYM', 'HOWARD STARK', 'PEGGY CARTER'], ['STEVE', 'NATASHA', 'SCOTT LANG'], ['STEVE', 'TONY'], ['RHODEY', 'SCOTT LANG', 'ROCKET', 'NEBULA'], ['ROCKET'], ['ROCKET', 'VALKYRIE'], [], ['THOR', 'ROCKET', 'KORG', 'MIEK'], ['NATASHA', 'CLINT BARTON'], ['TONY', 'THOR', 'ROCKET'], ['CLINT BARTON', 'RHODEY', 'SCOTT LANG', 'NEBULA'], ['STEVE', 'THOR', 'RHODEY', 'ROCKET', 'NEBULA'], ['CLINT BARTON'], [], ['CLINT BARTON'], ['TONY', 'NATASHA', 'CLINT BARTON', 'ROCKET'], ['STEVE', 'TONY', 'THOR', 'NATASHA', 'CLINT BARTON', 'RHODEY', 'SCOTT LANG', 'ROCKET', 'NEBULA', 'LOKI'], ['SCOTT LANG', 'ROCKET'], ['NATASHA', 'SCOTT LANG', 'NEBULA'], ['TONY', 'NATASHA'], ['STEVE'], ['STEVE'], ['STEVE', 'TONY', 'THOR', 'NATASHA', 'CLINT BARTON', 'RHODEY', 'ROCKET', 'NEBULA'], [], ['STEVE', 'TONY'], ['BRUCE BANNER', 'ANCIENT ONE'], ['THOR', 'ROCKET', 'FRIGGA', 'JANE FOSTER'], ['NATASHA', 'CLINT BARTON', 'RHODEY', 'NEBULA'], ['NATASHA', 'CLINT BARTON'], ['RHODEY', 'NEBULA'], ['NEBULA', 'GAMORA'], ['NEBULA', 'GAMORA'], ['NEBULA', 'GAMORA', 'THANOS'], ['RHODEY', 'NEBULA', 'GAMORA', 'THANOS'], [], ['STEVE', 'TONY', 'THOR', 'NATASHA', 'SCOTT LANG', 'LOKI'], ['STEVE', 'TONY'], ['STEVE', 'TONY', 'THOR', 'NATASHA', 'CLINT BARTON', 'SCOTT LANG', 'LOKI', 'BROCK RUMLOW'], ['STEVE', 'TONY'], ['STEVE', 'BROCK RUMLOW'], ['STEVE'], [], ['TONY', 'THOR', 'SCOTT LANG', 'LOKI'], ['TONY', 'SCOTT LANG'], ['TONY', 'THOR', 'LOKI', 'ALEXANDER PIERCE'], ['TONY', 'THOR', 'SCOTT LANG', 'LOKI', 'ALEXANDER PIERCE'], ['STEVE'], ['ANCIENT ONE'], [], ['STEVE', 'TONY', 'THOR', 'NATASHA', 'CLINT BARTON', 'RHODEY', 'ROCKET', 'NEBULA', 'GAMORA', 'EBONY MAW', 'THANOS'], ['THOR', 'FRIGGA'], ['THOR', 'ROCKET', 'JANE FOSTER'], ['THOR', 'FRIGGA'], ['THOR', 'ROCKET'], ['THOR', 'ROCKET', 'FRIGGA'], ['RHODEY', 'NEBULA', 'PETER QUILL'], ['RHODEY', 'NEBULA', 'THANOS'], ['THOR', 'BRUCE BANNER', 'NATASHA', 'RHODEY', 'NEBULA', 'GAMORA', 'EBONY MAW', 'THANOS'], ['NEBULA'], ['NEBULA'], ['NEBULA'], ['STEVE', 'TONY', 'SCOTT LANG'], ['TONY', 'STAN LEE'], ['STEVE', 'TONY'], ['STEVE', 'TONY'], ['TONY', 'HOWARD STARK'], ['STEVE', 'HANK PYM'], ['STEVE'], ['TONY', 'HOWARD STARK'], ['STEVE'], [], ['STEVE', 'PEGGY CARTER'], ['STEVE', 'TONY', 'HOWARD STARK', 'JARVIS'], [], ['NEBULA', 'GAMORA'], ['NEBULA'], [], ['NATASHA', 'CLINT BARTON'], ['NATASHA'], ['NATASHA', 'CLINT BARTON', 'RED SKULL'], ['NATASHA', 'CLINT BARTON', 'RED SKULL'], [], ['STEVE', 'TONY', 'THOR', 'RHODEY', 'ROCKET', 'NEBULA'], ['STEVE', 'TONY', 'THOR', 'CLINT BARTON'], ['STEVE', 'TONY', 'THOR', 'RHODEY', 'SCOTT LANG', 'ROCKET'], ['NEBULA'], ['STEVE', 'TONY', 'THOR', 'RHODEY', 'ROCKET', 'THANOS'], ['NEBULA'], [], ['STEVE', 'TONY', 'CLINT  ...

# %%
interact_data.head()
# Out:
#               STEVE  TONY  THOR  BRUCE BANNER  NATASHA  CLINT BARTON  RHODEY  \
# STEVE             0     0     0             0        0             0       0
# TONY              0     0     0             0        0             0       0
# THOR              0     0     0             0        0             0       0
# BRUCE BANNER      0     0     0             0        0             0       0
# NATASHA           0     0     0             0        0             0       0
#
#               CAROLE DANVERS  SCOTT LANG  ROCKET  ...  RED SKULL  \
# STEVE                      0           0       0  ...          0
# TONY                       0           0       0  ...          0
# THOR                       0           0       0  ...          0
# BRUCE BANNER               0           0       0  ...          0
# NATASHA                    0           0       0  ...          0
#
#               BROCK RUMLOW  JACK ROLINS  JASPER SITWELL  ALEXANDER PIERCE  \
# STEVE                    0            0               0                 0
# TONY                     0            0               0                 0
# THOR                     0            0               0                 0
# BRUCE BANNER             0            0               0                 0
# NATASHA                  0            0               0                 0
#
#               HOWARD STARK  PEGGY CARTER  JARVIS  STAN LEE  THANOS
# STEVE                    0             0       0         0       0
# TONY                     0             0       0         0       0
# THOR                     0             0       0         0       0
# BRUCE BANNER             0             0       0         0       0
# NATASHA                  0             0       0         0       0
#
# [5 rows x 60 columns]

# %%
for lst in all_charac_in_scene :
    for char in lst :
        i = 0
        while i < len(lst)-lst.index(char):
            char2 = lst[lst.index(char)+i]
            interact_data.at[char,char2] += 1
            i+=1

# %%
interact_data.head()
# Out:
#               STEVE  TONY  THOR  BRUCE BANNER  NATASHA  CLINT BARTON  RHODEY  \
# STEVE            54    29    19             3       19             7      18
# TONY              0    57    20             1       11             8      11
# THOR              0     0    34             3        9             6      15
# BRUCE BANNER      0     0     0             5        4             0       3
# NATASHA           0     0     0             0       30            11      12
#
#               CAROLE DANVERS  SCOTT LANG  ROCKET  ...  RED SKULL  \
# STEVE                      0          15      16  ...          0
# TONY                       0          13      12  ...          0
# THOR                       0           9      20  ...          0
# BRUCE BANNER               0           0       3  ...          0
# NATASHA                    0          11      10  ...          2
#
#               BROCK RUMLOW  JACK ROLINS  JASPER SITWELL  ALEXANDER PIERCE  \
# STEVE                    2            0               0                 0
# TONY                     1            0               0                 2
# THOR                     1            0               0                 2
# BRUCE BANNER             0            0               0                 0
# NATASHA                  1            0               0                 0
#
#               HOWARD STARK  PEGGY CARTER  JARVIS  STAN LEE  THANOS
# STEVE                    1             2       1         0       8
# TONY                     4             1       1         1       8
# THOR                     0             0       0         0       9
# BRUCE BANNER             0             0       0         0       2
# NATASHA                  0             0       0         0       3
#
# [5 rows x 60 columns]

# %%
G.add_nodes_from(characters_up)

for char1 in characters_up:
    for char2 in characters_up:
        weight = interact_data.at[char1, char2]
        if weight != 0 and char1 != '' and char2 != '':
            G.add_edges_from([(char1, char2, {"weight" : weight})])

# %%
G.nodes()
# Out:
# NodeView(('STEVE', 'TONY', 'THOR', 'BRUCE BANNER', 'NATASHA', 'CLINT BARTON', 'RHODEY', 'CAROLE DANVERS', 'SCOTT LANG', 'ROCKET', 'NEBULA', 'VALKYRIE', 'KORG', 'MIEK', 'WONG', 'OKOYE', 'RAMONDA', 'M’BAKU', 'CASSIE LANG', 'MAY', 'PEPPER POTTS', 'HAPPY HOGAN', 'SECRETARY ROSS', 'HARLEY KEENER', 'T’CHALLA', 'SHURI', 'DR. STRANGE', 'PETER PARKER', 'NED LEEDS', 'BUCKY BARNES', 'SAM WILSON', 'PETER QUILL', 'DRAX', 'MANTIS', 'GROOT', 'HOPE VAN DYNE', 'JANET VAN DYNE', 'HANK PYM', 'NICK FURY', 'MARIA HILL', 'LAURA BARTON', 'ANCIENT ONE', 'GAMORA', 'LOKI', 'FRIGGA', 'JANE FOSTER', 'EBONY MAW', 'PROXIMA', 'CULL OBSIDIAN', 'CORVUS GLAIVE', 'RED SKULL', 'BROCK RUMLOW', 'JACK ROLINS', 'JASPER SITWELL', 'ALEXANDER PIERCE', 'HOWARD STARK', 'PEGGY CARTER', 'JARVIS', 'STAN LEE', 'THANOS'))

# %%
# Compute the degree assortativity of the network using networkx tools
r = nx.degree_assortativity_coefficient(G)
print(f"The assortativity of the graph is: {r:3.1f}")
# Out:
# The assortativity of the graph is: -0.1

# %%
# Perform community detection using Louvain algorithm
# more: https://github.com/taynaud/python-louvain

# compute the best partition
partition = community_louvain.best_partition(G)
pos = nx.spring_layout(G, seed=4321, k=3)

fig = plt.figure(figsize=(20, 10))
communities_colors = ["#ff0000", "#02f51b", "#fc8505", "#d3fc05", "#00a1f2", "#ce00f2", "#6a5d7a", "#113832", "#421408"]

nb_communities = max(partition.values()) +1
for i in range(nb_communities):
    nb_community = 0
    for key, value in partition.items():
        if value == i:
            nb_community += 1
    percentage = nb_community*100/len(partition)            
    nx.draw_networkx_nodes(G, pos, [k for k, v in partition.items() if v == i], cmap=plt.cm.RdYlBu, label = "{} ({})%".format(nb_community, round(percentage)), node_color=communities_colors[i] )

nx.draw_networkx_edges(G, pos, alpha=0.1)
nx.draw_networkx_labels(G, pos)
plt.legend(title="Per community")
plt.show()

# %%
# kcore decomposition
def k_core_decomposition(graph):#graph should be a copy, not the original graph. 
    k = 1
    store_k_shell = {}
    nodes = [n for n in graph.nodes()]
    for node in nodes:
        if graph.degree(node) == 0:
            graph.remove_node(node)

    while graph.number_of_nodes() != 0:
        to_prune = [key1 for key1, v in {key: graph.degree(key) for key in graph.nodes()}.items() if v == k]
        k_shell = []
        while len(to_prune) > 0:
            i = to_prune.pop(0)
            neighbors = [l for l in graph.neighbors(i)] 
            for j in neighbors:
                if j in graph.nodes() and graph.degree(j)-1 == k:
                    to_prune.append(j)
            k_shell.append(i)
            graph.remove_node(i)
        #store shell
        if len(k_shell) != 0: store_k_shell[k] = k_shell
        k += 1
    
    return store_k_shell

# %%
# kcore decomposition
k_core_graph = k_core_decomposition(G.copy())

#Barabasi-Albert network
size = len(G.nodes())
average_degree = int(G.number_of_edges()/size)
barabasi_graph = nx.barabasi_albert_graph(size, average_degree)
k_core_with_barabasi_graph = k_core_decomposition(barabasi_graph.copy())

# display degree distribution for both graph to make comparison
fig1, axes1 = plt.subplots(1, 2, figsize=(12,5))
axes_titles = ["Initial graph", "Barabasi-Albert network"]
graphs = [G.copy(), barabasi_graph.copy()]
fig1.suptitle('degree distribution')
#fig1.text(0.04, 0.5, 'Numbers of nodes', va='center', rotation='vertical')

for i, ax in enumerate(axes1):
    data = {k: v for k, v in graphs[i].degree()}
    ax.hist(data.values(), bins="auto")
    ax.set_ylabel('Numbers of nodes')
    ax.set_title(axes_titles[i])
    ax.set_xlabel('Degree')

#k_shell comparison
fig2, axes2 = plt.subplots(1, 2, figsize=(12,5))
fig2.suptitle('kcore properties')
#fig2.text(0.5, 0.04, 'k_shell', ha='center')
#fig2.text(0.04, 0.5, 'Numbers of nodes', va='center', rotation='vertical')
k_cores_outputs = [k_core_graph, k_core_with_barabasi_graph]
for i, ax in enumerate(axes2):
    data = {k: len(v) for k, v in k_cores_outputs[i].items()}
    ax.set_title(axes_titles[i])
    ax.set_xlabel('k-shell')
    ax.set_ylabel('Numbers of nodes')
    ax.bar(data.keys(), data.values())
    
# Clustering coefficient
fig3, axes3 = plt.subplots(1, 2, figsize=(12,5))
fig3.suptitle('Clustering coefficient')
for i, ax in enumerate(axes3):    
    ax.set_title(axes_titles[i])
    ax.set_xlabel('Coefficient')
    ax.set_ylabel('Numbers of nodes')
    ax.hist(nx.clustering(graphs[i]).values())

# %%
# Influence Maximization Problem

# Simulate the spread process using Independent Cascade Model over the graph
def spread_process(graph, A0, probability=.25, max_iter=500):
    """
    Input: graph object, set of seed nodes, propagation probability and the 
            number of simulations
    Output: average number of nodes activated by the set of seed nodes
    """
    number_spread = []
    for i in range(max_iter):
        active, new_active = A0[:], A0[:]
        np.random.seed(i)
        while new_active:
            # For each newly activated nodes ...
            new_actived_nodes = []
            for node in new_active:
                # ... Determine neighbors that become activated ...
                neighbors = [n for n in graph.neighbors(node)]
                success = np.random.uniform(0, 1, len(neighbors)) < probability
                new_actived_nodes += list(np.extract(success, neighbors))
            new_active = list(set(new_actived_nodes) - set(active))
            #... add the newly activated nodes that doesn't exist in the final 
            # list of activated nodes
            active += new_active
            
        number_spread.append(len(active))
    return np.mean(number_spread)
    
    
# greedy algorithm: find the k nodes with the largest spread using the ICM
def greedy_algorithm(graph, percentage_k=0.05, probability=.1, max_iter=10):
    """
    Input:  graph object, propagation probability and the 
            number of simulations            
    Output: optimal seed set, resulting spread
    """
    k = int(percentage_k*graph.number_of_nodes()) #seed sets size
    A0 = []
    spreads = []
    all_spreads_executed = []
    times = []
    start_time = time.time()
    all_time_executed = []
    
    for _ in range(k):
        best_node = None
        best_spread = -np.inf
        
        for node in set(graph.nodes()) - set(A0):
            # Get a spread
            A = A0 + [node]
            average_nodes_spread = spread_process(graph, A, probability, max_iter)
            # Get the best average number of nodes activated by the set of seed nodes 
            if average_nodes_spread > best_spread:
                best_spread, best_node = average_nodes_spread, node
            all_time_executed.append(round(time.time() - start_time, 3))
            all_spreads_executed.append(average_nodes_spread)
        times.append(round(time.time() - start_time, 3))
        A0.append(best_node)
        spreads.append(best_spread)
    return (A0, spreads, times, all_spreads_executed, all_time_executed)

# %%
A0, spreads, times, all_spreads_executed, all_time_executed = greedy_algorithm(G.copy())
print("The set of seeds :", str(A0))
print("The average proportion of \"infected\" people at time t :", str(spreads))
print("the time :", str(times))

# %%
#Display the curve
plt.plot(times, spreads, color='r')
plt.scatter(all_time_executed, all_spreads_executed, alpha=0.3)
plt.ylabel('The total average proportion of “infected” people')
plt.xlabel('The discrete time')
plt.title("Influence Maximization Problem")
plt.show()
